# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.feature_selection import SelectKBest, mutual_info_classif

# %%
combined_table = pd.read_csv('Consumer complaint.csv')

# %%
X = combined_table['Consumer complaint narrative']
y = combined_table['Product']

# %%
vectorizer = TfidfVectorizer()
X_vectorized = vectorizer.fit_transform(X)

# %%
mi_scores = mutual_info_classif(X_vectorized, y)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# ...
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)

# %%
sorted_features = np.array(vectorizer.get_feature_names_out())[np.argsort(mi_scores)[::-1]]

# %%
k = 1000  
selected_features = sorted_features[:k]

# %%
X_selected = X_vectorized[:, [vectorizer.vocabulary_.get(feature) for feature in selected_features]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# %%
svm_model = SVC()
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
new_complaint = "The loan servicer provided incorrect information about loan forgiveness options. "

# %%
new_complaint_vectorized = vectorizer.transform([new_complaint])
new_complaint_selected = new_complaint_vectorized[:, [vectorizer.vocabulary_.get(feature) for feature in selected_features]]

# %%
predicted_class = svm_model.predict(new_complaint_selected)
print(f"The new complaint belongs to the class: {predicted_class}")
# Out:
# The new complaint belongs to the class: ['Mortgage']

# %%
new_complaint = "The bank incorrectly processed my deposit and withdrew the wrong amount. "
new_complaint_vectorized = vectorizer.transform([new_complaint])
new_complaint_selected = new_complaint_vectorized[:, [vectorizer.vocabulary_.get(feature) for feature in selected_features]]

# %%
predicted_class = svm_model.predict(new_complaint_selected)
print(f"The new complaint belongs to the class: {predicted_class}")
# Out:
# The new complaint belongs to the class: ['Bank account or service']

# %%
new_complaint = "I believe the debt they are trying to collect is not mine. "
new_complaint_vectorized = vectorizer.transform([new_complaint])
new_complaint_selected = new_complaint_vectorized[:, [vectorizer.vocabulary_.get(feature) for feature in selected_features]]

# %%
predicted_class = svm_model.predict(new_complaint_selected)
print(f"The new complaint belongs to the class: {predicted_class}")
# Out:
# The new complaint belongs to the class: ['Debt collection']

# %%
new_complaint = "There are errors on my credit report that need to be corrected. "
new_complaint_vectorized = vectorizer.transform([new_complaint])
new_complaint_selected = new_complaint_vectorized[:, [vectorizer.vocabulary_.get(feature) for feature in selected_features]]

# %%
predicted_class = svm_model.predict(new_complaint_selected)
print(f"The new complaint belongs to the class: {predicted_class}")
# Out:
# The new complaint belongs to the class: ['Credit reporting']

# %%
y_pred = svm_model.predict(X_test)

# %%
accuracy = np.mean(y_pred == y_test)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.7233333333333334

# %%
print(classification_report(y_test, y_pred))
# Out:
#                          precision    recall  f1-score   support
#
# Bank account or service       0.86      0.55      0.67        22
#           Consumer Loan       1.00      0.13      0.23        23
#             Credit card       0.62      0.66      0.64        32
#        Credit reporting       0.74      0.82      0.78        67
#         Debt collection       0.67      0.87      0.76        70
#         Money transfers       0.00      0.00      0.00         2
#                Mortgage       0.75      0.87      0.81        67
#             Payday loan       0.00      0.00      0.00         2
#            Prepaid card       0.00      0.00      0.00         3
#            Student loan       1.00      0.58      0.74        12
#
#                accuracy                           0.72       300
#               macro avg       0.56      0.45      0.46       300
#            weighted avg       0.74      0.72      0.69       300
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
